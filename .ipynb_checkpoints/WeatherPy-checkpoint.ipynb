# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 627

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = f"http://api.openweathermap.org/data/2.5/weather?&units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# # Loop through all the cities in our list to fetch weather data
# for i, city in enumerate(cities):
        
#     # Group cities in sets of 50 for logging purposes
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 0

#     # Create endpoint URL with each city
#     city_url = f"{url}&q={cities}"
    
#     # Log the url, record, and set numbers
#     print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

#     # Add 1 to the record count
#     record_count += 1
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | mrirt
# Processing Record 4 of Set 1 | beloha
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | chivay
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | kabinda
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | sosva
# Processing Record 13 of Set 1 | guerrero negro
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | umm kaddadah
# Processing Record 17 of Set 1 | morros
# Processing Record 18 of Set 1 | preobrazheniye
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | cap-aux-meules
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | carnarvon
# ...

# %%
 # Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1 
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather =requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 27 of Set 25 | new norfolk
# Processing Record 28 of Set 25 | rikitea
# Processing Record 29 of Set 25 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 25 | beloha
# Processing Record 31 of Set 25 | jamestown
# Processing Record 32 of Set 25 | chivay
# Processing Record 33 of Set 25 | georgetown
# Processing Record 34 of Set 25 | chokurdakh
# Processing Record 35 of Set 25 | kabinda
# Processing Record 36 of Set 25 | hobart
# Processing Record 37 of Set 25 | ponta do sol
# Processing Record 38 of Set 25 | sosva
# Processing Record 39 of Set 25 | guerrero negro
# Processing Record 40 of Set 25 | ushuaia
# Processing Record 41 of Set 25 | vaini
# Processing Record 42 of Set 25 | umm kaddadah
# Processing Record 43 of Set 25 | morros
# Processing Record 44 of Set 25 | preobrazheniye
# Processing Record 45 of Set 25 | mataura
# Processing Record 46 of Set 25 | cap-aux-meules
# Processing Record 47 of Set 25 | kapaa
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  new norfolk -42.7826  147.0587     11.51        61           1        1.34
# 1      rikitea -23.1203 -134.9692     25.54        75          41        2.64
# 2       beloha -25.1667   45.0500     23.35        85         100        6.11
# 3    jamestown  42.0970  -79.2353     -0.20        97         100        2.24
# 4       chivay -15.6383  -71.6011      9.57        93          97        2.81
#
#   Country        Date
# 0      AU  1675713500
# 1      PF  1675713501
# 2      MG  1675713501
# 3      US  1675713501
# 4      PE  1675713502

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        new norfolk -42.7826  147.0587     11.51        61           1
# 1            rikitea -23.1203 -134.9692     25.54        75          41
# 2             beloha -25.1667   45.0500     23.35        85         100
# 3          jamestown  42.0970  -79.2353     -0.20        97         100
# 4             chivay -15.6383  -71.6011      9.57        93          97
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      AU  1675713500
# 1              2.64      PF  1675713501
# 2              6.11      MG  1675713501
# 3              2.24      US  1675713501
# 4              2.81      PE  1675713502

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", marker="o")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs Max Temperature ({date})")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", marker="o")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs Max Humidity ({date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", marker="o")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs Cloudiness ({date})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", marker="o")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs Wind Speed ({date})")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_values, "r-")
    plt.annotate(line_eq, text_coord, fontsize = 10, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3           jamestown  42.0970  -79.2353     -0.20        97         100
# 5          georgetown   5.4112  100.3354     24.96        94          20
# 6          chokurdakh  70.6333  147.9167    -31.11        99         100
# 9        ponta do sol  32.6667  -17.1000     16.35        59          19
# 10              sosva  59.1766   61.8558    -22.66       100         100
#
#          Wind Speed Country        Date
# City_ID
# 3              2.24      US  1675713501
# 5              3.09      MY  1675712752
# 6              1.53      RU  1675713502
# 9              4.19      PT  1675713503
# 10             1.35      RU  1675713504

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        new norfolk -42.7826  147.0587     11.51        61           1
# 1            rikitea -23.1203 -134.9692     25.54        75          41
# 2             beloha -25.1667   45.0500     23.35        85         100
# 4             chivay -15.6383  -71.6011      9.57        93          97
# 7            kabinda  -6.1333   24.4833     19.73        73          69
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      AU  1675713500
# 1              2.64      PF  1675713501
# 2              6.11      MG  1675713501
# 4              2.81      PE  1675713502
# 7              0.55      CD  1675713503

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (6,-20))
# Out:
# The r-value is 0.7523243349183147

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55,35))
# Out:
# The r-value is 0.10806804442752582

# %% [markdown]
# **Discussion about the linear relationship:**
#
#
# -With a r-value of 0.75 for the northern hemisphere, there is a strong correlation between max temp and latitude.
#
# -With a r-value of 0.11 for the southern hemisphere, there is not a correlation between max temp and latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (50,45))
# Out:
# The r-value is 0.23678190618401382

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values,"Humidity", (-55,73))
# Out:
# The r-value is 0.08276800623509176

# %% [markdown]
# **Discussion about the linear relationship:**
#
# -With a r-value of 0.24 for the northern hemisphere, there is weak correlation between latitude and humidity.
#
# -With a r-value of 0.08 for the northern hemisphere, there is not a correlation between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (50,45))
# Out:
# The r-value is 0.09681642386902677

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values,"Cloudiness", (-55,73))
# Out:
# The r-value is 0.1904541329741092

# %% [markdown]
# **Discussion about the linear relationship:**
#
# -With r-values below the 0.3 threshold, there does not seem to be a correlation between cloudiness and latitude for either the northern or southern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (50,45))
# Out:
# The r-value is 0.0003618058573601765

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values,"Wind Speed", (-55,73))
# Out:
# The r-value is 0.09131392006429094

# %% [markdown]
# **Discussion about the linear relationship:
#
# -Much like cloudiness, the r-values for both the northern and southern hemispheres is well below 0.3. There is no correlation for wind speed and latitude.
